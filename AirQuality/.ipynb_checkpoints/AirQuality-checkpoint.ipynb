# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
pio.templates.default = "plotly_white"

data = pd.read_csv("delhiaqi.csv")
print(data.head())

data['date'] = pd.to_datetime(data['date'])

print(data.describe())

fig = go.Figure()

for pollutant in ['co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3']:
    fig.add_trace(go.Scatter(x=data['date'], y=data[pollutant], mode='lines',
                             name=pollutant))
    
fig.update_layout(title='Time Series Analysis of Air Pollutants in Delhi',
                  xaxis_title='Date', yaxis_title='Concentration (ug/m3)')

fig.show()
# Out:
#                   date       co     no    no2    o3    so2   pm2_5    pm10  \
# 0  2023-01-01 00:00:00  1655.58   1.66  39.41  5.90  17.88  169.29  194.64
# 1  2023-01-01 01:00:00  1869.20   6.82  42.16  1.99  22.17  182.84  211.08
# 2  2023-01-01 02:00:00  2510.07  27.72  43.87  0.02  30.04  220.25  260.68
# 3  2023-01-01 03:00:00  3150.94  55.43  44.55  0.85  35.76  252.90  304.12
# 4  2023-01-01 04:00:00  3471.37  68.84  45.24  5.45  39.10  266.36  322.80
#
#      nh3
# 0   5.83
# 1   7.66
# 2  11.40
# 3  13.55
# 4  14.19
#                       date            co          no         no2          o3  \
# count                  561    561.000000  561.000000  561.000000  561.000000
# mean   2023-01-12 16:00:00   3814.942210   51.181979   75.292496   30.141943
# min    2023-01-01 00:00:00    654.220000    0.000000   13.370000    0.000000
# 25%    2023-01-06 20:00:00   1708.980000    3.380000   44.550000    0.070000
# 50%    2023-01-12 16:00:00   2590.180000   13.300000   63.750000   11.800000
# 75%    2023-01-18 12:00:00   4432.680000   59.010000   97.330000   47.210000
# max    2023-01-24 08:00:00  16876.220000  425.580000  263.210000  164.510000
# std                    NaN   3227.744681   83.904476   42.473791   39.979405
#
#               so2        pm2_5         pm10         nh3
# count  561.000000   561.000000   561.000000  561.000000
# mean    64.655936   358.256364   420.988414   26.425062
# min      5.250000    60.100000    69.080000    0.630000
# 25%     28.130000   204.450000   240.900000    8.230000
# 50%     47.210000   301.170000   340.900000   14.820000
# 75%     77.250000   416.650000   482.570000   26.350000
# max    511.170000  1310.200000  1499.270000  267.510000
# std     61.073080   227.359117   271.287026   36.563094

# %%
# Define AQI breakpoints and corresponding AQI values
aqi_breakpoints = [
    (0, 12.0, 50), (12.1, 35.4, 100), (35.5, 55.4, 150),
    (55.5, 150.4, 200), (150.5, 250.4, 300), (250.5, 350.4, 400),
    (350.5, 500.4, 500)
]

def calculate_aqi(pollutant_name, concentration):
    for low, high, aqi in aqi_breakpoints:
        if low <= concentration <= high:
            return aqi
    return None

def calculate_overall_aqi(row):
    aqi_values = []
    pollutants = ['co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10', 'nh3']
    for pollutant in pollutants:
        aqi = calculate_aqi(pollutant, row[pollutant])
        if aqi is not None:
            aqi_values.append(aqi)
    return max(aqi_values)

# Calculate AQI for each row
data['AQI'] = data.apply(calculate_overall_aqi, axis=1)

# Define AQI categories
aqi_categories = [
    (0, 50, 'Good'), (51, 100, 'Moderate'), (101, 150, 'Unhealthy for Sensitive Groups'),
    (151, 200, 'Unhealthy'), (201, 300, 'Very Unhealthy'), (301, 500, 'Hazardous')
]

def categorize_aqi(aqi_value):
    for low, high, category in aqi_categories:
        if low <= aqi_value <= high:
            return category
    return None

# Categorize AQI
data['AQI Category'] = data['AQI'].apply(categorize_aqi)
print(data.head())
# Out:
#                  date       co     no    no2    o3    so2   pm2_5    pm10  \
# 0 2023-01-01 00:00:00  1655.58   1.66  39.41  5.90  17.88  169.29  194.64
# 1 2023-01-01 01:00:00  1869.20   6.82  42.16  1.99  22.17  182.84  211.08
# 2 2023-01-01 02:00:00  2510.07  27.72  43.87  0.02  30.04  220.25  260.68
# 3 2023-01-01 03:00:00  3150.94  55.43  44.55  0.85  35.76  252.90  304.12
# 4 2023-01-01 04:00:00  3471.37  68.84  45.24  5.45  39.10  266.36  322.80
#
#      nh3  AQI    AQI Category
# 0   5.83  300  Very Unhealthy
# 1   7.66  300  Very Unhealthy
# 2  11.40  400       Hazardous
# 3  13.55  400       Hazardous
# 4  14.19  400       Hazardous

# %%
# AQI over time
fig = px.bar(data, x="date", y="AQI",
             title="AQI of Delhi in January")
fig.update_xaxes(title="Date")
fig.update_yaxes(title="AQI")
fig.show()

# %%
fig = px.histogram(data, x="date", 
                    color="AQI Category", 
                    title="AQI Category Distribution Over Time")
fig.update_xaxes(title="Date")
fig.update_yaxes(title="Count")
fig.show()
# Out:
# <bound method BaseFigure.show of Figure({
#     'data': [{'alignmentgroup': 'True',
#               'bingroup': 'x',
#               'hovertemplate': 'AQI Category=Very Unhealthy<br>date=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Very Unhealthy',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': 'Very Unhealthy',
#               'offsetgroup': 'Very Unhealthy',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'histogram',
#               'x': array([datetime.datetime(2023, 1, 1, 0, 0),
#                           datetime.datetime(2023, 1, 1, 1, 0),
#                           datetime.datetime(2023, 1, 1, 7, 0),
#                           datetime.datetime(2023, 1, 1, 8, 0),
#                           datetime.datetime(2023, 1, 1, 9, 0),
#                           datetime.datetime(2023, 1, 1, 10, 0),
#                           datetime.datetime(2023, 1, 1, 14, 0),
#                           datetime.datetime(2023, 1, 1, 15, 0),
#                           datetime.datetime(2023, 1, 1, 16, 0),
#                           datetime.datetime(2023, 1, 1, 17, 0),
#                           datetime.datetime(2023, 1, 1, 18, 0),
#                           datetime.datetime(2023, 1, 1, 19, 0),
#                           datetime.datetime(2023, 1, 1, 20, 0),
#                           datetime.datetime(2023, 1, 1, 21, 0),
#                           datetime.datetime(2023, 1, 2, 2, 0),
#                           datetime.datetime(2023, 1, 2, 5, 0),
#                           datetime.datetime(2023, 1, 2, 6, 0),
#                           datetime.datetime(2023, 1, 2, 11, 0),
#                           datetime.datetime(2023, 1, 2, 12, 0),
#                           datetime.datetime(2023, 1, 2, 15, 0),
#                           datetime.datetime(2023, 1, 2, 16, 0),
#                           datetime.datetime(2023, 1, 3, 2, 0),
#                           datetime.datetime(2023, 1, 3, 3, 0),
#                           datetime.datetime(2023, 1, 3, 8, 0),
#                           datetime.datetime(2023, 1, 3, 9, 0),
#                           datetime.datetime(2023, 1, 3, 10, 0),
#                           datetime.datetime(2023, 1, 3, 20, 0),
#                           datetime.datetime(2023, 1, 3, 21, 0),
#                           datetime.datetime(2023, 1, 3, 22, 0),
#                           datetime.datetime(2023, 1, 3, 23, 0),
#                           datetime.datetime(2023, 1, 4, 0, 0),
#                           datetime.datetime(2023, 1, 4, 1, 0),
#                           datetime.datetime(2023, 1, 4, 9, 0),
#                           datetime.datetime(2023, 1, 5, 9, 0),
#                           datetime.datetime(2023, 1, 5, 13, 0),
#                           datetime.datetime(2023, 1, 5, 14, 0),
#                           datetime.datetime(2023, 1, 5, 15, 0),
#                           datetime.datetime(2023, 1, 5, 16, 0),
#                           datetime.datetime(2023, 1, 6, 5, 0),
#                           datetime.datetime(2023, 1, 6, 6, 0),
#                           datetime.datetime(2023, 1, 6, 7, 0),
#                           datetime.datetime(2023, 1, 6, 8, 0),
#                           datetime.datetime(2023, 1, 6, 9, 0),
#                           datetime.datetime(2023, 1, 6, 12, 0),
#                           datetime.datetime(2023, 1, 7, 4, 0),
#                           datetime.datetime(2023, 1, 7, 5, 0),
#                           datetime.datetime(2023, 1, 7, 6, 0),
#                           datetime.datetime(2023, 1, 7, 7, 0),
#                           datetime.datetime(2023, 1, 7, 8, 0),
#                           datetime.datetime(2023, 1, 7, 9, 0),
#                           datetime.datetime(2023, 1, 7, 20, 0),
#                           datetime.datetime(2023, 1, 7, 21, 0),
#                           datetime.datetime(2023, 1, 7, 22, 0),
#                           datetime.datetime(2023, 1, 7, 23, 0),
#                           datetime.datetime(2023, 1, 9, 11, 0),
#                           datetime.datetime(2023, 1, 9, 12, 0),
#                           datetime.datetime(2023, 1, 9, 13, 0),
#                           datetime.datetime(2023, 1, 9, 14, 0),
#                           datetime.datetime(2023, 1, 9, 15, 0),
#                           datetime.datetime(2023, 1, 9, 16, 0),
#                           datetime.datetime(2023, 1, 9, 17, 0),
#                           datetime.datetime(2023, 1, 9, 18, 0),
#                           datetime.datetime(2023, 1, 11, 11, 0),
#                           datetime.datetime(2023, 1, 11, 12, 0),
#                           datetime.datetime(2023, 1, 11, 13, 0),
#                           datetime.datetime(2023, 1, 11, 14, 0),
#                           datetime.datetime(2023, 1, 11, 15, 0),
#                           datetime.datetime(2023, 1, 13, 7, 0),
#                           datetime.datetime(2023, 1, 13, 8, 0),
#                           datetime.datetime(2023, 1, 13, 9, 0),
#                           datetime.datetime(2023, 1, 14, 8, 0),
#                           datetime.datetime(2023, 1, 14, 11, 0),
#                           datetime.datetime(2023, 1, 14, 12, 0),
#                           datetime.datetime(2023, 1, 14, 13, 0),
#                           datetime.datetime(2023, 1, 14, 14, 0),
#                           datetime.datetime(2023, 1, 14, 15, 0),
#                           datetime.datetime(2023, 1, 14, 16, 0),
#                           datetime.datetime(2023, 1, 14, 17, 0),
#                           datetime.datetime(2023, 1, 14, 18, 0),
#                           datetime.datetime(2023, 1, 14, 19, 0),
#                           datetime.datetime(2023, 1, 14, 20, 0),
#                           datetime.datetime(2023, 1, 14, 21, 0),
#                           datetime.datetime(2023, 1, 14, 22, 0),
#                           datetime.datetime(2023, 1, 14, 23, 0),
#                           datetime.datetime(2023, 1, 15, 0, 0),
#                           datetime.datetime(2023, 1, 15, 1, 0),
#                           datetime.datetime(2023, 1, 15, 2, 0),
#                           datetime.datetime(2023, 1, 15, 3, 0),
#                           datetime.datetime(2023, 1, 15, 4, 0),
#                           datetime.datetime(2023, 1, 15, 5, 0),
#                           datetime.datetime(2023, 1, 15, 13, 0),
#                           datetime.datetime(2023, 1, 15, 14, 0),
#                           datetime.datetime(2023, 1, 15, 15, 0),
#                           datetime.datetime(2023, 1, 15, 16, 0),
#                           datetime.datetime(2023, 1, 15, 17, 0),
#                           datetime.datetime(2023, 1, 15, 18, 0),
#                           datetime.datetime(2023, 1, 15, 22, 0),
#                           datetime.datetime(2023, 1, 15, 23, 0),
#                           datetime.datetime(2023, 1, 16, 0, 0),
#                           datetime.datetime(2023, 1, 16, 1, 0),
#                           datetime.datetime(2023, 1, 16, 11, 0),
#                           datetime.datetime(2023, 1, 16, 12, 0),
#                           datetime.datetime(2023, 1, 16, 18, 0),
#                           datetime.datetime(2023, 1, 16, 19, 0),
#                           datetime.datetime(2023, 1, 16, 20, 0),
#                           datetime.datetime(2023, 1, 16, 21, 0),
#                           datetime.datetime(2023, 1, 16, 22, 0),
#                           datetime.datetime(2023, 1, 16, 23, 0),
#                           datetime.datetime(2023, 1, 17, 0, 0),
#                           datetime.datetime(2023, 1, 17, 1, 0),
#                           datetime.datetime(2023, 1, 17, 7, 0),
#                           datetime.datetime(2023, 1, 17, 8, 0),
#                           datetime.datetime(2023, 1, 17, 9, 0),
#                           datetime.datetime(2023, 1, 17, 10, 0),
#                           datetime.datetime(2023, 1, 17, 11, 0),
#                           datetime.datetime(2023, 1, 17, 12, 0),
#                           datetime.datetime(2023, 1, 18, 7, 0),
#                           datetime.datetime(2023, 1, 18, 8, 0),
#                           datetime.datetime(2023, 1, 18, 9, 0),
#                           datetime.datetime(2023, 1, 18, 14, 0),
#                           datetime.datetime(2023, 1, 18, 23, 0),
#                           datetime.datetime(2023, 1, 19, 0, 0),
#                           datetime.datetime(2023, 1, 19, 1, 0),
#                           datetime.datetime(2023, 1, 19, 7, 0),
#                           datetime.datetime(2023, 1, 19, 8, 0),
#                           datetime.datetime(2023, 1, 19, 9, 0),
#                           datetime.datetime(2023, 1, 19, 11, 0),
#                           datetime.datetime(2023, 1, 20, 8, 0),
#                           datetime.datetime(2023, 1, 20, 13, 0),
#                           datetime.datetime(2023, 1, 20, 14, 0),
#                           datetime.datetime(2023, 1, 20, 22, 0),
#                           datetime.datetime(2023, 1, 20, 23, 0),
#                           datetime.datetime(2023, 1, 21, 0, 0),
#                           datetime.datetime(2023, 1, 21, 1, 0),
#                           datetime.datetime(2023, 1, 21, 7, 0),
#                           datetime.datetime(2023, 1, 21, 8, 0),
#                           datetime.datetime(2023, 1, 21, 9, 0),
#                           datetime.datetime(2023, 1, 21, 23, 0),
#                           datetime.datetime(2023, 1, 22, 0, 0),
#                           datetime.datetime(2023, 1, 22, 1, 0),
#                           datetime.datetime(2023, 1, 22, 2, 0),
#                           datetime.datetime(2023, 1, 22, 3, 0),
#                           datetime.datetime(2023, 1, 22, 4, 0),
#                           datetime.datetime(2023, 1, 22, 5, 0),
#                           datetime.datetime(2023, 1, 22, 6, 0),
#                           datetime.datetime(2023, 1, 22, 7, 0),
#                           datetime.datetime(2023, 1, 22, 8, 0),
#                           datetime.datetime(2023, 1, 22, 9, 0),
#                           datetime.datetime(2023, 1, 22, 10, 0),
#                           datetime.datetime(2023, 1, 22, 11, 0),
#                           datetime.datetime(2023, 1, 22, 16, 0),
#                           datetime.datetime(2023, 1, 22, 17, 0),
#                           datetime.datetime(2023, 1, 22, 18, 0),
#                           datetime.datetime(2023, 1, 22, 19, 0),
#                           datetime.datetime(2023, 1, 22, 20, 0),
#                           datetime.datetime(2023, 1, 22, 21, 0),
#                           datetime.datetime(2023, 1, 22, 22, 0),
#                           datetime.datetime(2023, 1, 22, 23, 0),
#                           datetime.datetime(2023, 1, 23, 0, 0),
#                           datetime.datetime(2023, 1, 23, 1, 0),
#                           datetime.datetime(2023, 1, 23, 2, 0),
#                           datetime.datetime(2023, 1, 23, 3, 0),
#                           datetime.datetime(2023, 1, 23, 4, 0),
#                           datetime.datetime(2023, 1, 23, 5, 0),
#                           datetime.datetime(2023, 1, 23, 6, 0),
#                           datetime.datetime(2023, 1, 23, 7, 0),
#                           datetime.datetime(2023, 1, 23, 8, 0),
#                           datetime.datetime(2023, 1, 23, 10, 0),
#                           datetime.datetime(2023, 1, 23, 13, 0),
#                           datetime.datetime(2023, 1, 23, 16, 0),
#                           datetime.datetime(2023, 1, 23, 17, 0),
#                           datetime.datetime(2023, 1, 23, 18, 0),
#                           datetime.datetime(2023, 1, 24, 7, 0)], dtype=object),
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'alignmentgroup': 'True',
#               'bingroup': 'x',
#               'hovertemplate': 'AQI Category=Hazardous<br>date=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Hazardous',
#               'marker': {'color': '#EF553B', 'pattern': {'shape': ''}},
#               'name': 'Hazardous',
#               'offsetgroup': 'Hazardous',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'histogram',
#               'x': array([datetime.datetime(2023, 1, 1, 2, 0),
#                           datetime.datetime(2023, 1, 1, 3, 0),
#                           datetime.datetime(2023, 1, 1, 4, 0), ...,
#                           datetime.datetime(2023, 1, 24, 4, 0),
#                           datetime.datetime(2023, 1, 24, 5, 0),
#                           datetime.datetime(2023, 1, 24, 6, 0)], dtype=object),
#               'xaxis': 'x',
#               'yaxis': 'y'},
#              {'alignmentgroup': 'True',
#               'bingroup': 'x',
#               'hovertemplate': 'AQI Category=Unhealthy<br>date=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Unhealthy',
#               'marker': {'color': '#00cc96', 'pattern': {'shape': ''}},
#               'name': 'Unhealthy',
#               'offsetgroup': 'Unhealthy',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'histogram',
#               'x': array([datetime.datetime(2023, 1, 1, 22, 0),
#                           datetime.datetime(2023, 1, 1, 23, 0),
#                           datetime.datetime(2023, 1, 2, 0, 0),
#                           datetime.datetime(2023, 1, 2, 1, 0),
#                           datetime.datetime(2023, 1, 2, 17, 0),
#                           datetime.datetime(2023, 1, 2, 18, 0),
#                           datetime.datetime(2023, 1, 2, 19, 0),
#                           datetime.datetime(2023, 1, 2, 20, 0),
#                           datetime.datetime(2023, 1, 2, 21, 0),
#                           datetime.datetime(2023, 1, 2, 22, 0),
#                           datetime.datetime(2023, 1, 2, 23, 0),
#                           datetime.datetime(2023, 1, 3, 0, 0),
#                           datetime.datetime(2023, 1, 3, 1, 0),
#                           datetime.datetime(2023, 1, 3, 4, 0),
#                           datetime.datetime(2023, 1, 3, 5, 0),
#                           datetime.datetime(2023, 1, 3, 6, 0),
#                           datetime.datetime(2023, 1, 5, 17, 0),
#                           datetime.datetime(2023, 1, 5, 18, 0),
#                           datetime.datetime(2023, 1, 6, 16, 0),
#                           datetime.datetime(2023, 1, 6, 17, 0),
#                           datetime.datetime(2023, 1, 6, 18, 0),
#                           datetime.datetime(2023, 1, 6, 19, 0),
#                           datetime.datetime(2023, 1, 8, 15, 0),
#                           datetime.datetime(2023, 1, 8, 16, 0),
#                           datetime.datetime(2023, 1, 8, 17, 0),
#                           datetime.datetime(2023, 1, 8, 18, 0),
#                           datetime.datetime(2023, 1, 9, 19, 0),
#                           datetime.datetime(2023, 1, 13, 22, 0),
#                           datetime.datetime(2023, 1, 15, 6, 0),
#                           datetime.datetime(2023, 1, 15, 7, 0),
#                           datetime.datetime(2023, 1, 15, 8, 0),
#                           datetime.datetime(2023, 1, 15, 9, 0),
#                           datetime.datetime(2023, 1, 15, 10, 0),
#                           datetime.datetime(2023, 1, 15, 11, 0),
#                           datetime.datetime(2023, 1, 15, 12, 0),
#                           datetime.datetime(2023, 1, 15, 19, 0),
#                           datetime.datetime(2023, 1, 15, 20, 0),
#                           datetime.datetime(2023, 1, 15, 21, 0),
#                           datetime.datetime(2023, 1, 16, 7, 0),
#                           datetime.datetime(2023, 1, 16, 8, 0),
#                           datetime.datetime(2023, 1, 16, 9, 0),
#                           datetime.datetime(2023, 1, 16, 10, 0),
#                           datetime.datetime(2023, 1, 18, 15, 0),
#                           datetime.datetime(2023, 1, 18, 16, 0),
#                           datetime.datetime(2023, 1, 18, 17, 0),
#                           datetime.datetime(2023, 1, 18, 18, 0),
#                           datetime.datetime(2023, 1, 20, 2, 0),
#                           datetime.datetime(2023, 1, 20, 3, 0),
#                           datetime.datetime(2023, 1, 20, 9, 0),
#                           datetime.datetime(2023, 1, 20, 10, 0),
#                           datetime.datetime(2023, 1, 20, 11, 0),
#                           datetime.datetime(2023, 1, 20, 12, 0),
#                           datetime.datetime(2023, 1, 23, 9, 0),
#                           datetime.datetime(2023, 1, 23, 19, 0),
#                           datetime.datetime(2023, 1, 23, 20, 0),
#                           datetime.datetime(2023, 1, 23, 21, 0),
#                           datetime.datetime(2023, 1, 24, 8, 0)], dtype=object),
#               'xaxis': 'x',
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'title': {'text': 'AQI Category'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'AQI Category Distribution Over Time'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Date'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Count'}}}
# })>
